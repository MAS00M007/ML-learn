# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
ds = pd.read_csv("HousePrice.csv")
ds.head(3)
# Out:
#    Bedrooms  Bathrooms  Sqft_living  Sqft_lot  Floors  Waterfront  View  \
# 0         6       3.00         2400      9373     2.0           0     0
# 1         6       3.00         2400      9373     2.0           0     0
# 2         4       1.75         2060     26036     1.0           0     0
#
#    Condition  Sqft_above  Sqft_basement  Yr_built  Yr_renovated     Price
# 0          3        2400              0      1991             0  280000.0
# 1          3        2400              0      1991             0  300000.0
# 2          4        1160            900      1947             0  647500.0

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data=ds.corr(),annot=True)
plt.show()

# %%
sns.pairplot(data=ds)
plt.show()

# %%
x = ds.iloc[:,:-1]
y = ds["Price"]

# %%
sc = StandardScaler()
sc.fit(x)
# Out:
# StandardScaler()

# %%
x = pd.DataFrame(sc.transform(x),columns=x.columns)
x
# Out:
#        Bedrooms  Bathrooms  Sqft_living  Sqft_lot    Floors  Waterfront  \
# 0      2.826929   1.149449     0.348534 -0.138436  0.936506   -0.087173
# 1      2.826929   1.149449     0.348534 -0.138436  0.936506   -0.087173
# 2      0.676485  -0.473621    -0.021667  0.263862 -0.915427   -0.087173
# 3     -0.398737  -1.447464    -0.674963  0.673427 -0.915427   -0.087173
# 4     -0.398737  -1.447464    -0.707628 -0.181266  0.010539   -0.087173
# ...         ...        ...          ...       ...       ...         ...
# 21608  1.751707  -0.149007    -0.522528 -0.264102  0.010539   -0.087173
# 21609 -1.473959  -1.447464    -1.132271 -0.186747 -0.915427   -0.087173
# 21610 -0.398737  -1.447464    -1.066941 -0.265067 -0.915427   -0.087173
# 21611 -1.473959  -0.473621    -0.729405 -0.340466  0.010539   -0.087173
# 21612 -0.398737  -1.447464    -0.827399 -0.169171 -0.915427   -0.087173
#
#            View  Condition  Sqft_above  Sqft_basement  Yr_built  Yr_renovated
# 0     -0.305759  -0.629187    0.738595      -0.658681  0.680729     -0.210128
# 1     -0.305759  -0.629187    0.738595      -0.658681  0.680729     -0.210128
# 2     -0.305759   0.907554   -0.758860       1.374919 -0.817259     -0.210128
# 3     -0.305759  -0.629187   -0.396573      -0.658681 -0.647033     -0.210128
# 4     -0.305759   0.907554   -0.940004       0.290333 -1.396027     -0.210128
# ...         ...        ...         ...            ...       ...           ...
# 21608 -0.305759  -0.629187   -0.227505      -0.658681 -1.498163     -0.210128
# 21609 -0.305759   2.444294   -1.145300      -0.206770 -1.089621     -0.210128
# 21610 -0.305759   0.907554   -1.290215       0.199950 -0.987485     -0.210128
# 21611 -0.305759  -0.629187   -1.072843       0.493693  1.361632     -0.210128
# 21612 -0.305759  -0.629187   -1.096995       0.335524 -0.953440     -0.210128
#
# [21613 rows x 12 columns]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.25,random_state=8)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression ,Lasso,Ridge

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)*100
# Out:
# 59.89280473013989

# %%
print(mean_squared_error(y_test,lr.predict(x_test)))
print(mean_absolute_error(y_test,lr.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,lr.predict(x_test))))
# Out:
# 51310183520.064835
# 151020.94016174838
# 226517.51261230296

# %%
plt.figure(figsize=(15,5))
plt.bar(x.columns,lr.coef_)
plt.title("LinearRegression")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %% [markdown]
# # Lasso (L1 Regularization)

# %%
la = Lasso(alpha=10)
la.fit(x_train,y_train)
print(la.alpha)
la.score(x_test,y_test)*100
# Out:
# 10
# C:\Users\masoo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.405e+12, tolerance: 2.225e+11
#   model = cd_fast.enet_coordinate_descent(
# 59.89243591781701

# %%
print(mean_squared_error(y_test,la.predict(x_test)))
print(mean_absolute_error(y_test,la.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,la.predict(x_test))))
# Out:
# 51310655351.312164
# 151020.20665983317
# 226518.55409946482

# %%
plt.figure(figsize=(15,5))
plt.bar(x.columns,la.coef_)
plt.title("Lasso")
plt.xlabel("columns")
plt.ylabel("lasso coef")
plt.show()

# %% [markdown]
# # Ridge

# %%
ri = Ridge(alpha=10)
ri.fit(x_train,y_train)
ri.score(x_test,y_test)*100
# Out:
# 59.89356094405508

# %%
print(mean_squared_error(y_test,ri.predict(x_test)))
print(mean_absolute_error(y_test,ri.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,ri.predict(x_test))))
# Out:
# 51309216075.83175
# 151006.39861418027
# 226515.37712886458

# %%
plt.figure(figsize=(15,5))
plt.bar(x.columns,ri.coef_)
plt.title("Ridge")
plt.xlabel("columns")
plt.ylabel("Ridge coef")
plt.show()

# %%
print("L1: ",la.score(x_test,y_test)*100)
print("L2: ",ri.score(x_test,y_test)*100)
# Out:
# L1:  59.89243591781701
# L2:  59.89356094405508

# %%
import pandas as pd

# %%
df=pd.DataFrame({"sizes": ["s","m","l","xl","m","xl","s","s","m","l","l","xl","s","s","xl","m"]})
df.head(3)
# Out:
#   sizes
# 0     s
# 1     m
# 2     l

# %%
ord_data = [["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=ord_data)
oe.fit(df[["sizes"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
df["en_sizes"]=oe.transform(df[["sizes"]])

# %%
df
# Out:
#    sizes  en_sizes
# 0      s       0.0
# 1      m       1.0
# 2      l       2.0
# 3     xl       3.0
# 4      m       1.0
# 5     xl       3.0
# 6      s       0.0
# 7      s       0.0
# 8      m       1.0
# 9      l       2.0
# 10     l       2.0
# 11    xl       3.0
# 12     s       0.0
# 13     s       0.0
# 14    xl       3.0
# 15     m       1.0

# %%
ord_data1={"s":0,"m":1,"l":2,"xl":3}

# %%
df["en_size_map"] = df["sizes"].map(ord_data1)

# %%
df
# Out:
#    sizes  en_sizes  en_size_map
# 0      s       0.0            0
# 1      m       1.0            1
# 2      l       2.0            2
# 3     xl       3.0            3
# 4      m       1.0            1
# 5     xl       3.0            3
# 6      s       0.0            0
# 7      s       0.0            0
# 8      m       1.0            1
# 9      l       2.0            2
# 10     l       2.0            2
# 11    xl       3.0            3
# 12     s       0.0            0
# 13     s       0.0            0
# 14    xl       3.0            3
# 15     m       1.0            1

# %%
ds=pd.read_csv("loan.csv")
ds.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
ds["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
ds["Property_Area"].fillna(ds["Property_Area"].mode()[0],inplace=True)

# %%
ds["Property_Area"].isnull().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_data2 = [["Rural","Semiurban","Urban"]]

# %%
oe2  = OrdinalEncoder(categories=ord_data2)

# %%
ds["Property_Area"]=oe2.fit_transform(ds[["Property_Area"]])

# %%
ds["Property_Area"]
# Out:
# 0      2.0
# 1      0.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 609    0.0
# 610    0.0
# 611    2.0
# 612    2.0
# 613    1.0
# Name: Property_Area, Length: 614, dtype: float64

# %%
ds.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

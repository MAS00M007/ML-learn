# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("Salary_Data.csv")
ds.head(3)
# Out:
#    Age  Experience  Salary
# 0   29           7   42996
# 1   23           0   21790
# 2   39          15   45774

# %%
ds.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=ds)
plt.show()

# %%
X = ds[['Age', 'Experience']]
y = ds['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt = DecisionTreeRegressor(max_depth=1)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
dt.score(x_test,y_test)*100
# Out:
# 59.960987848738334

# %%
dt.score(x_train,y_train)*100
# Out:
# 51.28586268235698

# %%
plot_tree(decision_tree=dt)
plt.show()

# %%
for i in range(1,20):
    dt1 = DecisionTreeRegressor(max_depth=i)
    dt1.fit(x_train,y_train)
    print(dt1.score(x_train,y_train)*100,dt1.score(x_test,y_test)*100,i)
# Out:
# 51.28586268235698 59.960987848738334 1
# 72.65529350654174 43.307656641513134 2
# 79.03944783646378 45.088353659546435 3
# 83.92121831699109 28.63749965320076 4
# 87.67678630933715 2.9628041780158765 5
# 90.55270183273154 10.040293625444075 6
# 93.2339720773294 -3.324634231514456 7
# 95.25309745966426 -11.113844921290973 8
# 97.43750764013977 -0.10404386530600274 9
# 97.69895934171593 -10.656093421918268 10
# 97.71431203768034 -0.08860582613825496 11
# 97.71431203768034 -10.682195888833101 12
# 97.71431203768034 -5.421618496421954 13
# 97.71431203768034 -11.14330319389456 14
# 97.71431203768034 -7.134593298354619 15
# 97.71431203768034 -1.86478229068896 16
# 97.71431203768034 -0.5497131311997139 17
# 97.71431203768034 -7.166194129663639 18
# 97.71431203768034 -1.86478229068896 19

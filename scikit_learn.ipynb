# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("loan.csv")
ds.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
ds.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
ds.select_dtypes(include="float64").columns
# Out:
# Index(['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term',
#        'Credit_History'],
#       dtype='object')

# %%
ds.select_dtypes(include="int64").columns
# Out:
# Index(['ApplicantIncome'], dtype='object')

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.7 MB 9.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.9/8.7 MB 10.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.0/8.7 MB 8.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.8/8.7 MB 7.1 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 5.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.4 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.4 MB 6.0 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/38.4 MB 6.2 MB/s eta 0:00:06
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")
arr = si.fit_transform(ds[['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term',
       'Credit_History']])

# %%
newDs = pd.DataFrame(arr,columns=ds.select_dtypes(include="float64").columns)

# %%
newDs.isnull().sum()
# Out:
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# dtype: int64

# %%
newDs
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 0                  0.0  146.412162             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0   71.000000             360.0             1.0
# 610                0.0   40.000000             180.0             1.0
# 611              240.0  253.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
# [614 rows x 4 columns]

# %%
ds["LoanAmount"].mean()
# Out:
# np.float64(146.41216216216216)

# %%
arr2 = si.fit_transform(ds[['ApplicantIncome']])

# %%
pd.DataFrame(arr2,columns=ds.select_dtypes(include="int64").columns)
# Out:
#      ApplicantIncome
# 0             5849.0
# 1             4583.0
# 2             3000.0
# 3             2583.0
# 4             6000.0
# ..               ...
# 609           2900.0
# 610           4106.0
# 611           8072.0
# 612           7583.0
# 613           4583.0
#
# [614 rows x 1 columns]

# %%
ds.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
